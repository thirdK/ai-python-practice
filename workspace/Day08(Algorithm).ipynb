# %%
# 정렬 알고리즘 sort algorithms

# 데이터를 오름차순 또는 내림차순으로 나열하는 알고리즘
# 검색엔진 엑셀 워드... 이미 많이 사용하고 있다.

# %%
# 단순 선택법 - 정렬되지 않은 데이터 중 가장 작은 데이터를 선택하여 맨 앞부터 순서대로
#             정렬해 나가는 알고리즘이다. (선택정렬, 선택법, 단순 선택법...)

# %%
#  0  1  2  3  4
# 12 13 11 14 10

# 우선 가장 작은 숫자와 첫번째 숫자와 교환한다.

# 10 <--고정 13 11 14 12
# 교환된 숫자는 고정되며 나머지 숫자중 가장 작은 숫자를 찾는다.
# 10 11 <--고정 13 14 12
# 반복한다.

# 단순 선택법 알고리즘
# 1. 탐색 범위에서 최소값을 찾는 처리
# 2. 탐색 범위의 맨 앞 요소와 최소값을 교환하는 처리

# %% [markdown]
# ![11.%EC%A0%95%EB%A0%AC_%EB%8B%A8%EC%88%9C%EC%84%A0%ED%83%9D%EB%B2%9501.jpg](attachment:11.%EC%A0%95%EB%A0%AC_%EB%8B%A8%EC%88%9C%EC%84%A0%ED%83%9D%EB%B2%9501.jpg)

# %%
# 잠정적인 최소값의 인덱스를 저장하는 변수 indexMin 을 준비한다.
# 그때그때 마다의 최소값의 첨자를 저장할 변수 indexMin를 만든다.

# arr[indexMin] 와 요소들의 비교처리는 같은 절차의 반복이다. i는 0~4까지 순차적으로
# 변하면서 반복된다. 이 변하는 구조의 첨자는 변수 k로 나타내 보자.
# k의 초기값은 1 최대 4까지이다.

# %% [markdown]
# ![11.%EC%A0%95%EB%A0%AC_%EB%8B%A8%EC%88%9C%EC%84%A0%ED%83%9D%EB%B2%9502.jpg](attachment:11.%EC%A0%95%EB%A0%AC_%EB%8B%A8%EC%88%9C%EC%84%A0%ED%83%9D%EB%B2%9502.jpg)

# %%
# 잠정 최소값과 비교하는 요소의 첨자를 변수 k로 치환하여 반복 구조로 만들었다.
# 이대로라면 k에 무한루프가 발생된다. 반복 구조는 언제나 종료 조건이 필수이다.

# i가 0일때 k는 1부터 4까지 변하게 된다. k는 5가 되는일은 절대 없다. 따라서
# 실행 조건은 k < 5으로 설계한다. 5이상이면 종료

# %% [markdown]
# ![11.%EC%A0%95%EB%A0%AC_%EB%8B%A8%EC%88%9C%EC%84%A0%ED%83%9D%EB%B2%9503.jpg](attachment:11.%EC%A0%95%EB%A0%AC_%EB%8B%A8%EC%88%9C%EC%84%A0%ED%83%9D%EB%B2%9503.jpg)

# %%
# 최소값과 arr[i]의 데이터를 교환

# %% [markdown]
# ![12.%EC%A0%95%EB%A0%AC_%EB%8B%A8%EC%88%9C%EC%84%A0%ED%83%9D%EB%B2%95_%EC%B5%9C%EC%A2%85.jpg](attachment:12.%EC%A0%95%EB%A0%AC_%EB%8B%A8%EC%88%9C%EC%84%A0%ED%83%9D%EB%B2%95_%EC%B5%9C%EC%A2%85.jpg)

# %%
# 단순 교환법 Bubble Sort

# 인접한 데이터를 교환하는 처리를 반복한다.

# index 0  1  2  3  4 
# data  5  3  4  1  2

# index번호의 가장 끝의 3, 4번을 비교
# data 1, 2는 이미 정렬 상태라서 넘어감

# index 2, 3 비교 (한칸씩 이동하면서 검사)
# data 4, 1 은 정렬 상태가 아니라서 1 , 4로 정렬

# index 0  1  2  3  4 
# data  5  3  1  4  2

# index 1, 2 비교
# data  3, 1 -> 1, 3

# index 0  1  2  3  4 
# data  5  1  3  4  2

# index 0, 1 비교
# data  5, 1 -> 1, 5

# index 0  1  2  3  4 
# data  1  5  3  4  2

# 1은 정렬이 완전히 끝난 상태로 확정됨
# 이후로도 같은 방식으로 반복하는데 정렬이 확정된 1은 범위에서 제외됨

# %%
#단순 교환법 bubble sort 알고리즘

# 1. 오른쪽 끝부터 순서대로 인접한 공을 오름차순 정렬한다.
# 2. 왼쪽 끝 칸 부터 순서대로 들어갈 공을 확정시켜 나간다.

# index 0  1  2  3  4 
# data  5  3  4  1  2

# 오른쪽 끝 인접한 공 2개(비교하는 요소)
# 오른쪽 요소 index를 i    arr[i]
# 왼쪽 요소 index는  i-1   arr[i-1]

# 정렬이 이미 되어있는 상태인지의 여부를 확인하려면 
# '왼쪽 요소가 오른쪽 요소보다 작은가??'
# arr[i-1] < arr[i]

# %% [markdown]
# ![13.%EC%A0%95%EB%A0%AC_%EB%8B%A8%EC%88%9C%EA%B5%90%ED%99%98%EB%B2%9501-2.jpg](attachment:13.%EC%A0%95%EB%A0%AC_%EB%8B%A8%EC%88%9C%EA%B5%90%ED%99%98%EB%B2%9501-2.jpg)

# %% [markdown]
# ![13.%EC%A0%95%EB%A0%AC_%EB%8B%A8%EC%88%9C%EA%B5%90%ED%99%98%EB%B2%9502.jpg](attachment:13.%EC%A0%95%EB%A0%AC_%EB%8B%A8%EC%88%9C%EA%B5%90%ED%99%98%EB%B2%9502.jpg)

# %%
# 여기까지는 순조롭게 비교와 교환처리가 진행된다.
# 마지막에 i-1이 0이 되고 i가 1이 되면
# 이미 확정된 arr[0]과 arr[1]을 비교하게 된다. 이것은 쓸데 없는 낭비가 된다.
# 그러면 어디를 수정해야 할까... i > 0 조건식이 문제로 보인다.
# 따라서 
# arr[1]를 확정하는 반복 처리부터는 i > 0 -->  i > 1 로 변경해야한다.
# 반복할 때마다 i>0, i>1, i>2, i>3......와 같이 늘려 가도록 변화하는 처리를 추가
# 변수 k로 표현하자 k의 초기값은 0부터 시작한다. i>k

# %% [markdown]
# ![13.%EC%A0%95%EB%A0%AC_%EB%8B%A8%EC%88%9C%EA%B5%90%ED%99%98%EB%B2%9503.jpg](attachment:13.%EC%A0%95%EB%A0%AC_%EB%8B%A8%EC%88%9C%EA%B5%90%ED%99%98%EB%B2%9503.jpg)

# %% [markdown]
# ![14.%EC%A0%95%EB%A0%AC_%EB%8B%A8%EC%88%9C%EA%B5%90%ED%99%98%EB%B2%95_%EC%B5%9C%EC%A2%85.jpg](attachment:14.%EC%A0%95%EB%A0%AC_%EB%8B%A8%EC%88%9C%EA%B5%90%ED%99%98%EB%B2%95_%EC%B5%9C%EC%A2%85.jpg)
