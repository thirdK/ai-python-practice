# %% [markdown]
# ![%EC%88%9C%EC%B0%A8_%EC%84%A0%ED%83%9D_%EB%B0%98%EB%B3%B5.jpg](attachment:%EC%88%9C%EC%B0%A8_%EC%84%A0%ED%83%9D_%EB%B0%98%EB%B3%B5.jpg)

# %%
# 삼각형의 면적을 계산하는 알고리즘

# 삼각형의 면적 = 밑변 * 높이 / 2


# 1.의사코드로 작성

# - 밑변과 높이를 입력
# - area <- base * height / 2
# - area 출력

# 2.플로우차트로 작성

# %% [markdown]
# ![%EC%88%9C%EC%84%9C%EB%8F%84_%EA%B8%B0%EB%B3%B8_%EC%82%BC%EA%B0%81%ED%98%95%EB%A9%B4%EC%A0%81.jpg](attachment:%EC%88%9C%EC%84%9C%EB%8F%84_%EA%B8%B0%EB%B3%B8_%EC%82%BC%EA%B0%81%ED%98%95%EB%A9%B4%EC%A0%81.jpg)

# %%
# 3.코드로 작성
base = int(input('밑변 >> '))
height = int(input('높이 >> '))

area = base * height / 2
print(area)
# Out:
# 밑변 >> 2
# 높이 >> 4
# 4.0

# %%
# 두 데이터의 대소를 판단하는 알고리즘

# # 의사코드
# - 두 데이터를 입력(a,b)
# - if a > b then a출력
# - elif a = b then 같다 출력
# - else then b를 출력
